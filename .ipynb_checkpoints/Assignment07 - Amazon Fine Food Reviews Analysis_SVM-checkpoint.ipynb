# %% [markdown]
# # Amazon Fine Food Reviews Analysis
#
#
# Data Source: https://www.kaggle.com/snap/amazon-fine-food-reviews <br>
#
# EDA: https://nycdatascience.com/blog/student-works/amazon-fine-foods-visualization/
#
#
# The Amazon Fine Food Reviews dataset consists of reviews of fine foods from Amazon.<br>
#
# Number of reviews: 568,454<br>
# Number of users: 256,059<br>
# Number of products: 74,258<br>
# Timespan: Oct 1999 - Oct 2012<br>
# Number of Attributes/Columns in data: 10
#
# Attribute Information:
#
# 1. Id
# 2. ProductId - unique identifier for the product
# 3. UserId - unqiue identifier for the user
# 4. ProfileName
# 5. HelpfulnessNumerator - number of users who found the review helpful
# 6. HelpfulnessDenominator - number of users who indicated whether they found the review helpful or not
# 7. Score - rating between 1 and 5
# 8. Time - timestamp for the review
# 9. Summary - brief summary of the review
# 10. Text - text of the review
#
#
# #### Objective:
# Given a review, determine whether the review is positive (rating of 4 or 5) or negative (rating of 1 or 2).
#
# <br>
# [Q] How to determine if a review is positive or negative?<br>
# <br>
# [Ans] We could use Score/Rating. A rating of 4 or 5 can be cosnidered as a positive review. A rating of 1 or 2 can be considered as negative one. A review of rating 3 is considered nuetral and such reviews are ignored from our analysis. This is an approximate and proxy way of determining the polarity (positivity/negativity) of a review.

# %% [markdown]
# # [1]. Reading Data

# %% [markdown]
# ## [1.1] Loading the data
#
# The dataset is available in two forms
# 1. .csv file
# 2. SQLite Database
#
# In order to load the data, We have used the SQLITE dataset as it is easier to query the data and visualise the data efficiently.
# <br>
#
# Here as we only want to get the global sentiment of the recommendations (positive or negative), we will purposefully ignore all Scores equal to 3. If the score is above 3, then the recommendation wil be set to "positive". Otherwise, it will be set to "negative".

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")


import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

from tqdm import tqdm
import os

# %%
# using SQLite Table to read data.
db_path = '/home/monodeepdas112/Datasets/amazon-fine-food-reviews/database.sqlite'
con = sqlite3.connect(db_path) 

# filtering only positive and negative reviews i.e. 
# not taking into consideration those reviews with Score=3
# SELECT * FROM Reviews WHERE Score != 3 LIMIT 500000, will give top 500000 data points
# you can change the number to any other number based on your computing power

filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3 LIMIT 100000""", con) 
# for tsne assignment you can take 5k data points

# filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3 LIMIT 5000""", con) 

# Give reviews with Score>3 a positive rating(1), and reviews with a score<3 a negative rating(0).
def partition(x):
    if x < 3:
        return 0
    return 1

#changing reviews with score less than 3 to be positive and vice-versa
actualScore = filtered_data['Score']
positiveNegative = actualScore.map(partition) 
filtered_data['Score'] = positiveNegative
print("Number of data points in our data", filtered_data.shape)
filtered_data.head(3)
# Out:
# Number of data points in our data (100000, 10)
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      1  1303862400
# 1                     0                       0      0  1346976000
# 2                     1                       1      1  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
display = pd.read_sql_query("""
SELECT UserId, ProductId, ProfileName, Time, Score, Text, COUNT(*)
FROM Reviews
GROUP BY UserId
HAVING COUNT(*)>1
""", con)

# %%
print(display.shape)
display.head()
# Out:
# (80668, 7)
#                UserId   ProductId             ProfileName        Time  Score  \
# 0  #oc-R115TNMSPFT9I7  B007Y59HVM                 Breyton  1331510400      2
# 1  #oc-R11D9D7SHXIJB9  B005HG9ET0  Louis E. Emory "hoppy"  1342396800      5
# 2  #oc-R11DNU2NBKQ23Z  B007Y59HVM        Kim Cieszykowski  1348531200      1
# 3  #oc-R11O5J5ZVQE25C  B005HG9ET0           Penguin Chick  1346889600      5
# 4  #oc-R12KPBODL2B5ZD  B007OSBE1U   Christopher P. Presta  1348617600      1
#
#                                                 Text  COUNT(*)
# 0  Overall its just OK when considering the price...         2
# 1  My wife has recurring extreme muscle spasms, u...         3
# 2  This coffee is horrible and unfortunately not ...         2
# 3  This will be the bottle that you grab from the...         3
# 4  I didnt like this coffee. Instead of telling y...         2

# %%
display[display['UserId']=='AZY10LLTJ71NX']
# Out:
#               UserId   ProductId                      ProfileName        Time  \
# 80638  AZY10LLTJ71NX  B006P7E5ZI  undertheshrine "undertheshrine"  1334707200
#
#        Score                                               Text  COUNT(*)
# 80638      5  I was recommended to try green tea extract to ...         5

# %%
display['COUNT(*)'].sum()
# Out:
# 393063

# %% [markdown]
# #  [2] Exploratory Data Analysis

# %% [markdown]
# ## [2.1] Data Cleaning: Deduplication
#
# It is observed (as shown in the table below) that the reviews data had many duplicate entries. Hence it was necessary to remove duplicates in order to get unbiased results for the analysis of the data.  Following is an example:

# %%
display= pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3 AND UserId="AR5J8UI46CURR"
ORDER BY ProductID
""", con)
display.head()
# Out:
#        Id   ProductId         UserId      ProfileName  HelpfulnessNumerator  \
# 0   78445  B000HDL1RQ  AR5J8UI46CURR  Geetha Krishnan                     2
# 1  138317  B000HDOPYC  AR5J8UI46CURR  Geetha Krishnan                     2
# 2  138277  B000HDOPYM  AR5J8UI46CURR  Geetha Krishnan                     2
# 3   73791  B000HDOPZG  AR5J8UI46CURR  Geetha Krishnan                     2
# 4  155049  B000PAQ75C  AR5J8UI46CURR  Geetha Krishnan                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       2      5  1199577600
# 1                       2      5  1199577600
# 2                       2      5  1199577600
# 3                       2      5  1199577600
# 4                       2      5  1199577600
#
#                              Summary  \
# 0  LOACKER QUADRATINI VANILLA WAFERS
# 1  LOACKER QUADRATINI VANILLA WAFERS
# 2  LOACKER QUADRATINI VANILLA WAFERS
# 3  LOACKER QUADRATINI VANILLA WAFERS
# 4  LOACKER QUADRATINI VANILLA WAFERS
#
#                                                 Text
# 0  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 1  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 2  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 3  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 4  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...

# %% [markdown]
# As it can be seen above that same user has multiple reviews with same values for HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary and Text and on doing analysis it was found that <br>
# <br>
# ProductId=B000HDOPZG was Loacker Quadratini Vanilla Wafer Cookies, 8.82-Ounce Packages (Pack of 8)<br>
# <br>
# ProductId=B000HDL1RQ was Loacker Quadratini Lemon Wafer Cookies, 8.82-Ounce Packages (Pack of 8) and so on<br>
#
# It was inferred after analysis that reviews with same parameters other than ProductId belonged to the same product just having different flavour or quantity. Hence in order to reduce redundancy it was decided to eliminate the rows having same parameters.<br>
#
# The method used for the same was that we first sort the data according to ProductId and then just keep the first similar product review and delelte the others. for eg. in the above just the review for ProductId=B000HDL1RQ remains. This method ensures that there is only one representative for each product and deduplication without sorting would lead to possibility of different representatives still existing for the same product.

# %%
#Sorting data according to ProductId in ascending order
sorted_data=filtered_data.sort_values('ProductId', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
#Deduplication of entries
final=sorted_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"}, keep='first', inplace=False)
final.shape
# Out:
# (87775, 10)

# %%
#Checking to see how much % of data still remains
(final['Id'].size*1.0)/(filtered_data['Id'].size*1.0)*100
# Out:
# 87.775

# %% [markdown]
# <b>Observation:-</b> It was also seen that in two rows given below the value of HelpfulnessNumerator is greater than HelpfulnessDenominator which is not practically possible hence these two rows too are removed from calcualtions

# %%
display= pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3 AND Id=44737 OR Id=64422
ORDER BY ProductID
""", con)

display.head()
# Out:
#       Id   ProductId          UserId              ProfileName  \
# 0  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
# 1  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     3                       1      5  1224892800
# 1                     3                       2      4  1212883200
#
#                                         Summary  \
# 0             Bought This for My Son at College
# 1  Pure cocoa taste with crunchy almonds inside
#
#                                                 Text
# 0  My son loves spaghetti so I didn't hesitate or...
# 1  It was almost a 'love at first bite' - the per...

# %%
final=final[final.HelpfulnessNumerator<=final.HelpfulnessDenominator]

# %%
#Before starting the next phase of preprocessing lets see the number of entries left
print(final.shape)

#How many positive and negative reviews are present in our dataset?
final['Score'].value_counts()
# Out:
# (87773, 10)
# 1    73592
# 0    14181
# Name: Score, dtype: int64

# %% [markdown]
# #  [3] Preprocessing

# %% [markdown]
# ## [3.1].  Preprocessing Review Text
#
# Now that we have finished deduplication our data requires some preprocessing before we go on further with analysis and making the prediction model.
#
# Hence in the Preprocessing phase we do the following in the order below:-
#
# 1. Begin by removing the html tags
# 2. Remove any punctuations or limited set of special characters like , or . or # etc.
# 3. Check if the word is made up of english letters and is not alpha-numeric
# 4. Check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters)
# 5. Convert the word to lowercase
# 6. Remove Stopwords
# 7. Finally Snowball Stemming the word (it was obsereved to be better than Porter Stemming)<br>
#
# After which we collect the words used to describe positive and negative reviews

# %%
# printing some random reviews
sent_0 = final['Text'].values[0]
print(sent_0)
print("="*50)

sent_1000 = final['Text'].values[1000]
print(sent_1000)
print("="*50)

sent_1500 = final['Text'].values[1500]
print(sent_1500)
print("="*50)

sent_4900 = final['Text'].values[4900]
print(sent_4900)
print("="*50)
# Out:
# My dogs loves this chicken but its a product from China, so we wont be buying it anymore.  Its very hard to find any chicken products made in the USA but they are out there, but this one isnt.  Its too bad too because its a good product but I wont take any chances till they know what is going on with the china imports.
# ==================================================
# The Candy Blocks were a nice visual for the Lego Birthday party but the candy has little taste to it.  Very little of the 2 lbs that I bought were eaten and I threw the rest away.  I would not buy the candy again.
# ==================================================
# was way to hot for my blood, took a bite and did a jig  lol
# ==================================================
# My dog LOVES these treats. They tend to have a very strong fish oil smell. So if you are afraid of the fishy smell, don't get it. But I think my dog likes it because of the smell. These treats are really small in size. They are great for training. You can give your dog several of these without worrying about him over eating. Amazon's price was much more reasonable than any other retailer. You can buy a 1 pound bag on Amazon for almost the same price as a 6 ounce bag at other retailers. It's definitely worth it to buy a big bag if your dog eats them a lot.
# ==================================================

# %%
# remove urls from text python: https://stackoverflow.com/a/40823105/4084039
sent_0 = re.sub(r"http\S+", "", sent_0)
sent_1000 = re.sub(r"http\S+", "", sent_1000)
sent_150 = re.sub(r"http\S+", "", sent_1500)
sent_4900 = re.sub(r"http\S+", "", sent_4900)

print(sent_0)
# Out:
# My dogs loves this chicken but its a product from China, so we wont be buying it anymore.  Its very hard to find any chicken products made in the USA but they are out there, but this one isnt.  Its too bad too because its a good product but I wont take any chances till they know what is going on with the china imports.

# %%
# https://stackoverflow.com/questions/16206380/python-beautifulsoup-how-to-remove-all-tags-from-an-element
from bs4 import BeautifulSoup

soup = BeautifulSoup(sent_0, 'lxml')
text = soup.get_text()
print(text)
print("="*50)

soup = BeautifulSoup(sent_1000, 'lxml')
text = soup.get_text()
print(text)
print("="*50)

soup = BeautifulSoup(sent_1500, 'lxml')
text = soup.get_text()
print(text)
print("="*50)

soup = BeautifulSoup(sent_4900, 'lxml')
text = soup.get_text()
print(text)
# Out:
# My dogs loves this chicken but its a product from China, so we wont be buying it anymore.  Its very hard to find any chicken products made in the USA but they are out there, but this one isnt.  Its too bad too because its a good product but I wont take any chances till they know what is going on with the china imports.
# ==================================================
# The Candy Blocks were a nice visual for the Lego Birthday party but the candy has little taste to it.  Very little of the 2 lbs that I bought were eaten and I threw the rest away.  I would not buy the candy again.
# ==================================================
# was way to hot for my blood, took a bite and did a jig  lol
# ==================================================
# My dog LOVES these treats. They tend to have a very strong fish oil smell. So if you are afraid of the fishy smell, don't get it. But I think my dog likes it because of the smell. These treats are really small in size. They are great for training. You can give your dog several of these without worrying about him over eating. Amazon's price was much more reasonable than any other retailer. You can buy a 1 pound bag on Amazon for almost the same price as a 6 ounce bag at other retailers. It's definitely worth it to buy a big bag if your dog eats them a lot.

# %%
# https://stackoverflow.com/a/47091490/4084039
import re

def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
sent_1500 = decontracted(sent_1500)
print(sent_1500)
print("="*50)
# Out:
# was way to hot for my blood, took a bite and did a jig  lol
# ==================================================

# %%
#remove words with numbers python: https://stackoverflow.com/a/18082370/4084039
sent_0 = re.sub("\S*\d\S*", "", sent_0).strip()
print(sent_0)
# Out:
# My dogs loves this chicken but its a product from China, so we wont be buying it anymore.  Its very hard to find any chicken products made in the USA but they are out there, but this one isnt.  Its too bad too because its a good product but I wont take any chances till they know what is going on with the china imports.

# %%
#remove spacial character: https://stackoverflow.com/a/5843547/4084039
sent_1500 = re.sub('[^A-Za-z0-9]+', ' ', sent_1500)
print(sent_1500)
# Out:
# was way to hot for my blood took a bite and did a jig lol

# %%
# https://gist.github.com/sebleier/554280
# we are removing the words from the stop words list: 'no', 'nor', 'not'
# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
# Combining all the above stundents 
from tqdm import tqdm
preprocessed_reviews = []
# tqdm is for printing the status bar
for sentance in tqdm(final['Text'].values):
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    preprocessed_reviews.append(sentance.strip())
# Out:
# 100%|██████████| 87773/87773 [00:42<00:00, 2061.01it/s]

# %%
preprocessed_reviews[1500]
# Out:
# 'way hot blood took bite jig lol'

# %% [markdown]
# <h2><font color='red'>[3.2] Preprocessing Review Summary</font></h2>

# %%
## Similartly you can do preprocessing for review summary also.

# %% [markdown]
# # [4] Featurization

# %% [markdown]
# ## [4.1] BAG OF WORDS

# %%
# #BoW
# count_vect = CountVectorizer() #in scikit-learn
# count_vect.fit(preprocessed_reviews)
# print("some feature names ", count_vect.get_feature_names()[:10])
# print('='*50)

# final_counts = count_vect.transform(preprocessed_reviews)
# print("the type of count vectorizer ",type(final_counts))
# print("the shape of out text BOW vectorizer ",final_counts.get_shape())
# print("the number of unique words ", final_counts.get_shape()[1])

# %% [markdown]
# ## [4.2] Bi-Grams and n-Grams.

# %%
# #bi-gram, tri-gram and n-gram

# #removing stop words like "not" should be avoided before building n-grams
# # count_vect = CountVectorizer(ngram_range=(1,2))
# # please do read the CountVectorizer documentation http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# # you can choose these numebrs min_df=10, max_features=5000, of your choice
# count_vect = CountVectorizer(ngram_range=(1,2), min_df=10, max_features=5000)
# final_bigram_counts = count_vect.fit_transform(preprocessed_reviews)
# print("the type of count vectorizer ",type(final_bigram_counts))
# print("the shape of out text BOW vectorizer ",final_bigram_counts.get_shape())
# print("the number of unique words including both unigrams and bigrams ", final_bigram_counts.get_shape()[1])

# %% [markdown]
# ## [4.3] TF-IDF

# %%
# tf_idf_vect = TfidfVectorizer(ngram_range=(1,2), min_df=10)
# tf_idf_vect.fit(preprocessed_reviews)
# print("some sample features(unique words in the corpus)",tf_idf_vect.get_feature_names()[0:10])
# print('='*50)

# final_tf_idf = tf_idf_vect.transform(preprocessed_reviews)
# print("the type of count vectorizer ",type(final_tf_idf))
# print("the shape of out text TFIDF vectorizer ",final_tf_idf.get_shape())
# print("the number of unique words including both unigrams and bigrams ", final_tf_idf.get_shape()[1])

# %% [markdown]
# ## [4.4] Word2Vec

# %%
# # Train your own Word2Vec model using your own text corpus
# i=0
# list_of_sentences=[]
# for sentence in preprocessed_reviews:
#     list_of_sentences.append(sentence.split())

# %%
# # Using Google News Word2Vectors

# # in this project we are using a pretrained model by google
# # its 3.3G file, once you load this into your memory 
# # it occupies ~9Gb, so please do this step only if you have >12G of ram
# # we will provide a pickle file wich contains a dict , 
# # and it contains all our courpus words as keys and  model[word] as values
# # To use this code-snippet, download "GoogleNews-vectors-negative300.bin" 
# # from https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit
# # it's 1.9GB in size.


# # http://kavita-ganesan.com/gensim-word2vec-tutorial-starter-code/#.W17SRFAzZPY
# # you can comment this whole cell
# # or change these varible according to your need

# is_your_ram_gt_16g=False
# want_to_use_google_w2v = False
# want_to_train_w2v = True

# if want_to_train_w2v:
#     # min_count = 5 considers only words that occured atleast 5 times
#     w2v_model=Word2Vec(list_of_sentance,min_count=5,size=50, workers=4)
#     print(w2v_model.wv.most_similar('great'))
#     print('='*50)
#     print(w2v_model.wv.most_similar('worst'))
    
# elif want_to_use_google_w2v and is_your_ram_gt_16g:
#     if os.path.isfile('GoogleNews-vectors-negative300.bin'):
#         w2v_model=KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
#         print(w2v_model.wv.most_similar('great'))
#         print(w2v_model.wv.most_similar('worst'))
#     else:
#         print("you don't have gogole's word2vec file, keep want_to_train_w2v = True, to train your own w2v ")

# %%
# w2v_words = list(w2v_model.wv.vocab)
# print("number of words that occured minimum 5 times ",len(w2v_words))
# print("sample words ", w2v_words[0:50])

# %% [markdown]
# ## [4.4.1] Converting text into vectors using Avg W2V, TFIDF-W2V

# %% [markdown]
# #### [4.4.1.1] Avg W2v

# %%
# # average Word2Vec
# # compute average word2vec for each review.
# sent_vectors = []; # the avg-w2v for each sentence/review is stored in this list
# for sent in tqdm(list_of_sentance): # for each review/sentence
#     sent_vec = np.zeros(50) # as word vectors are of zero length 50, you might need to change this to 300 if you use google's w2v
#     cnt_words =0; # num of words with a valid vector in the sentence/review
#     for word in sent: # for each word in a review/sentence
#         if word in w2v_words:
#             vec = w2v_model.wv[word]
#             sent_vec += vec
#             cnt_words += 1
#     if cnt_words != 0:
#         sent_vec /= cnt_words
#     sent_vectors.append(sent_vec)
# print(len(sent_vectors))
# print(len(sent_vectors[0]))

# %% [markdown]
# #### [4.4.1.2] TFIDF weighted W2v

# %%
# # S = ["abc def pqr", "def def def abc", "pqr pqr def"]
# model = TfidfVectorizer()
# tf_idf_matrix = model.fit_transform(preprocessed_reviews)
# # we are converting a dictionary with word as a key, and the idf as a value
# dictionary = dict(zip(model.get_feature_names(), list(model.idf_)))

# %%
# # TF-IDF weighted Word2Vec
# tfidf_feat = model.get_feature_names() # tfidf words/col-names
# # final_tf_idf is the sparse matrix with row= sentence, col=word and cell_val = tfidf

# tfidf_sent_vectors = []; # the tfidf-w2v for each sentence/review is stored in this list
# row=0;
# for sent in tqdm(list_of_sentance): # for each review/sentence 
#     sent_vec = np.zeros(50) # as word vectors are of zero length
#     weight_sum =0; # num of words with a valid vector in the sentence/review
#     for word in sent: # for each word in a review/sentence
#         if word in w2v_words and word in tfidf_feat:
#             vec = w2v_model.wv[word]
# #             tf_idf = tf_idf_matrix[row, tfidf_feat.index(word)]
#             # to reduce the computation we are 
#             # dictionary[word] = idf value of word in whole courpus
#             # sent.count(word) = tf valeus of word in this review
#             tf_idf = dictionary[word]*(sent.count(word)/len(sent))
#             sent_vec += (vec * tf_idf)
#             weight_sum += tf_idf
#     if weight_sum != 0:
#         sent_vec /= weight_sum
#     tfidf_sent_vectors.append(sent_vec)
#     row += 1

# %% [markdown]
# # [5] Assignment 7: SVM

# %% [markdown]
# <ol>
#     <li><strong>Apply SVM on these feature sets</strong>
#         <ul>
#             <li><font color='red'>SET 1:</font>Review text, preprocessed one converted into vectors using (BOW)</li>
#             <li><font color='red'>SET 2:</font>Review text, preprocessed one converted into vectors using (TFIDF)</li>
#             <li><font color='red'>SET 3:</font>Review text, preprocessed one converted into vectors using (AVG W2v)</li>
#             <li><font color='red'>SET 4:</font>Review text, preprocessed one converted into vectors using (TFIDF W2v)</li>
#         </ul>
#     </li>
#     <br>
#     <li><strong>Procedure</strong>
#         <ul>
#     <li>You need to work with 2 versions of SVM
#         <ul><li>Linear kernel</li>
#             <li>RBF kernel</li></ul>
#     <li>When you are working with linear kernel, use SGDClassifier’ with hinge loss because it is computationally less expensive.</li>
#     <li>When you are working with ‘SGDClassifier’ with hinge loss and trying to find the AUC
#         score, you would have to use <a href='https://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html'>CalibratedClassifierCV</a></li>
#     <li>Similarly, like kdtree of knn, when you are working with RBF kernel it's better to reduce
# the number of dimensions. You can put min_df = 10, max_features = 500 and consider a sample size of 40k points.</li>
#         </ul>
#     </li>
#     <br>
#     <li><strong>Hyper paramter tuning (find best alpha in range [10^-4 to 10^4], and the best penalty among 'l1', 'l2')</strong>
#         <ul>
#     <li>Find the best hyper parameter which will give the maximum <a href='https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/receiver-operating-characteristic-curve-roc-curve-and-auc-1/'>AUC</a> value</li>
#     <li>Find the best hyper paramter using k-fold cross validation or simple cross validation data</li>
#     <li>Use gridsearch cv or randomsearch cv or you can also write your own for loops to do this task of hyperparameter tuning</li>
#         </ul>
#     </li>
#     <br>
#     <li><strong>Feature importance</strong>
#         <ul>
#     <li>When you are working on the linear kernel with BOW or TFIDF please print the top 10 best
# features for each of the positive and negative classes.</li>
#         </ul>
#     </li>
#     <br>
#     <li><strong>Feature engineering</strong>
#         <ul>
#     <li>To increase the performance of your model, you can also experiment with with feature engineering like :</li>
#             <ul>
#             <li>Taking length of reviews as another feature.</li>
#             <li>Considering some features from review summary as well.</li>
#         </ul>
#         </ul>
#     </li>
#     <br>
#     <li><strong>Representation of results</strong>
#         <ul>
#     <li>You need to plot the performance of model both on train data and cross validation data for each hyper parameter, like shown in the figure.
#     <img src='train_cv_auc.JPG' width=300px></li>
#     <li>Once after you found the best hyper parameter, you need to train your model with it, and find the AUC on test data and plot the ROC curve on both train and test.
#     <img src='train_test_auc.JPG' width=300px></li>
#     <li>Along with plotting ROC curve, you need to print the <a href='https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/confusion-matrix-tpr-fpr-fnr-tnr-1/'>confusion matrix</a> with predicted and original labels of test data points. Please visualize your confusion matrices using <a href='https://seaborn.pydata.org/generated/seaborn.heatmap.html'>seaborn heatmaps.
#     <img src='confusion_matrix.png' width=300px></li>
#         </ul>
#     </li>
#     <br>
#     <li><strong>Conclusion</strong>
#         <ul>
#     <li>You need to summarize the results at the end of the notebook, summarize it in the table format. To print out a table please refer to this prettytable library<a href='http://zetcode.com/python/prettytable/'>  link</a>
#         <img src='summary.JPG' width=400px>
#     </li>
#         </ul>
# </ol>

# %% [markdown]
# <h4><font color='red'>Note: Data Leakage</font></h4>
#
# 1. There will be an issue of data-leakage if you vectorize the entire data and then split it into train/cv/test.
# 2. To avoid the issue of data-leakag, make sure to split your data first and then vectorize it.
# 3. While vectorizing your data, apply the method fit_transform() on you train data, and apply the method transform() on cv/test data.
# 4. For more details please go through this <a href='https://soundcloud.com/applied-ai-course/leakage-bow-and-tfidf'>link.</a>

# %% [markdown]
# # Applying SVM

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import pprint
from sklearn.pipeline import Pipeline
import os.path
import pickle
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### [5.0.0] Splitting up the Dataset into D_train and D_test

# %%
num_data_points = 100000

# %%
Dx_train, Dx_test, Dy_train, Dy_test = train_test_split(preprocessed_reviews[:num_data_points], final['Score'].tolist()[:num_data_points], test_size=0.30, random_state=42)

# %%
prettytable_data = []

# %% [markdown]
# ### [5.0.1] Defining some functions to increase code reusability and readability

# %%
'''Creating Custom Vectorizers for TFIDF - W2Vec and Avg - W2Vec'''
class Tfidf_W2Vec_Vectorizer(object):
    def __init__(self, w2vec_model):
        if(w2v_model is None):
            raise Exception('Word 2 Vector model passed to Tfidf_W2Vec Vectorizer is None !')
        self.tfidf = TfidfVectorizer(max_features=300)
        self.dictionary = None
        self.tfidf_feat = None
        
        self.word2vec = w2vec_model
        
    def fit(self, X):
        '''X : list'''
        #Initializing the TFIDF Vectorizer
        self.tfidf.fit_transform(X)
        # we are converting a dictionary with word as a key, and the idf as a value
        self.dictionary = dict(zip(self.tfidf.get_feature_names(), list(self.tfidf.idf_)))
        self.tfidf_feat = self.tfidf.get_feature_names()
        
        return self

    def transform(self, X):
        '''X : list'''
        return np.array([
                np.mean([self.word2vec[w] * self.dictionary[word]*(X.cout(word)/len(X))
                         for w in words if w in self.word2vec and w in self.tfidf_feat] or
                        [np.zeros(300)], axis=0)
                for words in X
            ])

class Avg_W2Vec_Vectorizer(object):
    def __init__(self, w2vec_model):
        if(w2v_model is None):
            raise Exception('Word 2 Vector model passed to Avg_W2Vec Vectorizer is None !')
        self.word2vec = w2vec_model

    def fit(self, X):
        return self

    def transform(self, X):
        '''X : list'''
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(300)], axis=0)
            for words in X
        ])

# %%
def get_vectorizer(vectorizer, train, W2V_model=None):
    if(vectorizer=='BOW'):
        vectorizer = CountVectorizer(ngram_range=(1,2), min_df=10, max_features=5000)
    if(vectorizer=='TFIDF'):
        vectorizer = TfidfVectorizer(ngram_range=(1,2), min_df=10, max_features=5000)
    if(vectorizer=='TFIDF-W2Vec'):
        vectorizer = Tfidf_W2Vec_Vectorizer(W2V_model)
    if(vectorizer=='Avg-W2Vec'):
        vectorizer = Avg_W2Vec_Vectorizer(W2V_model)
    
    vectorizer.fit(train)
    return vectorizer

# %%
'''Perform Simple Cross Validation'''
def perform_hyperparameter_tuning(X, Y, vectorizer, vec_name, penalty, results_path, retrain=False, W2V_model=None):
    #If the pandas dataframe with the hyperparameter info exists then return it

    if(retrain==False):
        # If Cross Validation results exists then return them
        if(os.path.exists(results_path)):
            return pd.read_csv(results_path)
        else:
            # If no data exists but retrain=False then mention accordingly
            print('Retrain is set to be False but no Cross Validation Results DataFrame was found !\nPlease set retrain to True.')
    else:
        # else perform hyperparameter tuning
        print('Performing Hyperparameter Tuning...\n')
        # regularization parameter
        alpha = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000]
        hyperparameters = {
            'svm__penalty' : penalty,
            'svm__alpha' : alpha
        }

        penalties = []
        alpha_values = []

        train_scores = []
        test_scores = []

        train_mean_score = []
        test_mean_score = []

        # Initializing KFold
        skf = StratifiedKFold(n_splits=3)
        X = np.array(X)
        Y = np.array(Y)

        for reg_param in hyperparameters['svm__alpha']:
            for penalty in hyperparameters['svm__penalty']:
                
                #Performing Cross Validation
                for train_index, test_index in skf.split(X, Y):
                    Dx_train, Dx_cv = X[train_index], X[test_index]
                    Dy_train, Dy_cv = Y[train_index], Y[test_index]

                    #Initializing the Vectorizer
                    vectorizer = get_vectorizer(vectorizer, Dx_train.tolist(), W2V_model)

                    #Transforming the data to features
                    x_train = vectorizer.transform(Dx_train.tolist())
                    x_cv = vectorizer.transform(Dx_cv.tolist())

                    #Initializing the LR model
                    svm = SGDClassifier(penalty=penalty, 
                                        alpha=reg_param, 
                                        max_iter=1000, verbose=0)

                    # Fit the model
                    svm.fit(x_train, Dy_train)

                    # Calibrating the svm model to output probablity class labels
                    calib_svm = CalibratedClassifierCV(base_estimator=svm, method="isotonic", cv="prefit")
                    calib_svm.fit(x_train, Dy_train)
                    
                    
                    #Prediction
                    train_results = calib_svm.predict_proba(x_train)
                    cv_results = calib_svm.predict_proba(x_cv)

                    try:
                        train_score = roc_auc_score(Dy_train, train_results[:, 1])
                        test_score = roc_auc_score(Dy_cv, cv_results[:, 1])

                        #storing the results to form a dataframe
                        train_scores.append(train_score)
                        test_scores.append(test_score)

                    except Exception as e:
                        print('Error Case : ', e)
                        print(('Actual, Predicted'))
                        [print((Dy_cv[i], cv_results[i, 1])) for i in range(len(Dy_cv))]
                    
                    print('CV iteration : alpha={0}, penalty={1}, train_score={2}, test_score={3}'
                      .format(reg_param, penalty, train_score, test_score))

                train_mean_score.append(sum(train_scores)/len(train_scores))
                test_mean_score.append(sum(test_scores)/len(test_scores))

                penalties.append(penalty)
                alpha_values.append(reg_param)

                print('C={0}, penalty={1}, train_score={2}, test_score={3}'
                      .format(reg_param, penalty, sum(train_scores)/len(train_scores), sum(test_scores)/len(test_scores)))

                
                train_scores = []
                test_scores = []
        
        # Creating a DataFrame from the saved data for visualization
        results_df = pd.DataFrame({'alpha' : alpha_values, 'penalty' : penalties, 
                                   'train_score' : train_mean_score, 
                                   'test_score': test_mean_score})
        
        #writing the results to csv after performing hyperparameter tuning
        try:
            results_df.to_csv(results_path)
        except Exception as ex:
            print(str(ex), "\nError occured while converting DataFrame to CSV after cross validation.")
        return results_df

# %%
def analyse_results(df):
    # plotting error curves
    fig = plt.figure()
    ax = fig.gca()

    plt.plot([math.log10(i) for i in df.alpha.tolist()], df.test_score.tolist(), '-o', c='b', label='Validation AUC')
    plt.plot([math.log10(i) for i in df.alpha.tolist()], df.train_score.tolist(), '-o', c='r', label='Train AUC')
    plt.grid(True)
    plt.xlabel('log10 of Hyperparameter alpha')
    plt.ylabel('Area Under ROC Curve')
    plt.title('AUC ROC Curve for Logistic Regression')
    plt.legend(loc='best')
    plt.show()
    
    # return the best parameters
    mmax = 0
    ind_max = 0
    for index, row in df.iterrows():
        if(row['test_score']>mmax):
            mmax=row['test_score']
            ind_max = index
        
        
    best_params = {
        'svm__alpha': df.loc[ind_max, 'alpha'], 
        'svm__penalty':df.loc[ind_max, 'penalty']
    }
    
    return best_params

# %%
def retrain_with_best_params(data, labels, best_params, vec_name, model_path, word2vec):
    if(os.path.exists(model_path)):
        print('Loading Model....')
        with open(model_path, 'rb') as input_file:
            calib_svm = pickle.load(input_file)
    else:
        svm = SGDClassifier(penalty=best_params['svm__penalty'], alpha=best_params['svm__alpha'], max_iter=1000, verbose=0)
        print('Initializing Vectorizer')
        vectorizer = get_vectorizer(vectorizer=vec_name, train=data, W2V_model=word2vec)
        print('Training Model....')
        svm.fit(vectorizer.transform(data), np.array(labels))
    
        calib_svm = CalibratedClassifierCV(base_estimator=svm, method="isotonic", cv="prefit")
        calib_svm.fit(vectorizer.transform(data), np.array(labels))
        
        print('Saving Trained Model....')
        with open(model_path,'wb') as file:
            pickle.dump(calib_svm, file)
    return calib_svm

# %%
def plot_confusion_matrix(model, data, labels, dataset_label):
    pred = model.predict(data)
    conf_mat = confusion_matrix(labels, pred)
    
    strings = strings = np.asarray([['TN = ', 'FP = '],
                                    ['FN = ', 'TP = ']])

    labels = (np.asarray(["{0}{1}".format(string, value)
                          for string, value in zip(strings.flatten(),
                                                   conf_mat.flatten())])
             ).reshape(2, 2)

    fig, ax = plt.subplots()
    ax.set(xlabel='Predicted', ylabel='Actual', title='Confusion Matrix : {0}'.format(dataset_label))
    sns.heatmap(conf_mat, annot=labels, fmt="", cmap='YlGnBu', ax=ax)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.set_xticklabels(['False', 'True'])
    ax.set_yticklabels(['False', 'True'])
    plt.show()

# %%
def plot_AUC_ROC(model, vectorizer, Dx_train, Dx_test, Dy_train, Dy_test):
    
    #predicting probability of Dx_test, Dx_train
    test_score = model.predict_proba(vectorizer.transform(Dx_test))
    train_score = model.predict_proba(vectorizer.transform(Dx_train))

    #Finding out the ROC_AUC_SCORE
    train_roc_auc_score = roc_auc_score(np.array(Dy_train), train_score[:, 1])
    print('Area Under the Curve for Train : ', train_roc_auc_score)
    test_roc_auc_score = roc_auc_score(np.array(Dy_test), test_score[:, 1])
    print('Area Under the Curve for Test : ', test_roc_auc_score)

    #Plotting with matplotlib.pyplot
    #ROC Curve for D-train
    train_fpr, train_tpr, thresholds = roc_curve(np.array(Dy_train), train_score[:, 1])
    plt.plot(train_fpr, train_tpr, label="train AUC ="+str(auc(train_fpr, train_tpr)))

    # #ROC Curve for D-test
    test_fpr, test_tpr, thresholds = roc_curve(np.array(Dy_test), test_score[:, 1])
    plt.plot(test_fpr, test_tpr, label="train AUC ="+str(auc(test_fpr, test_tpr)))
    
    plt.legend()
    plt.xlabel("FPR : False Positive Ratio")
    plt.ylabel("TPF : True Positive Ratio")
    plt.title("Area Under ROC Curve")
    plt.show()
    
    plot_confusion_matrix(model, vectorizer.transform(Dx_train), np.array(Dy_train), 'Training')
    plot_confusion_matrix(model, vectorizer.transform(Dx_test), np.array(Dy_test), 'Testing')
    return train_roc_auc_score, test_roc_auc_score

# %% [markdown]
# ## [5.1] Linear SVM

# %% [markdown]
# ### [5.1.1] Applying Linear SVM on BOW,<font color='red'> SET 1</font>

# %%
# Please write all the code with proper documentation
csv_path = 'saved_models/Assignment7/BOW_svm_results.csv'
cv_results = perform_hyperparameter_tuning(X=Dx_train, Y=Dy_train, vectorizer='BOW', vec_name='BOW', 
                                           penalty=['l1', 'l2'], results_path=csv_path, retrain=False, W2V_model=None)
# Analysing best parameters
best_parameters = analyse_results(cv_results)
pprint.pprint(best_parameters)
# retraining the model with best parameters
model_path = 'saved_models/Assignment7/{0}_svm.pkl'.format('BOW')
calibrated_svm = retrain_with_best_params(Dx_train, Dy_train, best_parameters, 'BOW', model_path, None)

print('Retraining Vectorizer with Dx_train')
vectorizer_obj = get_vectorizer(W2V_model = None, train=Dx_train, vectorizer='BOW')

# plotting AUC ROC 
train_score, test_score = plot_AUC_ROC(calibrated_svm, vectorizer_obj, Dx_train, Dx_test, Dy_train, Dy_test)

# appending the data results
prettytable_data.append(['BOW', 'SVM', best_parameters['svm__penalty'], best_parameters['svm__alpha'], train_score, test_score])
# Out:
# {'svm__alpha': 0.001, 'svm__penalty': 'l2'}
# Loading Model....
# Retraining Vectorizer with Dx_train
# Area Under the Curve for Train :  0.9672225756871394
# Area Under the Curve for Test :  0.9492080705021025

# %% [markdown]
# ### [5.1.2] Applying Linear SVM on TFIDF,<font color='red'> SET 2</font>

# %%
# Please write all the code with proper documentation
csv_path = 'saved_models/Assignment7/TFIDF_svm_results.csv'
cv_results = perform_hyperparameter_tuning(X=Dx_train, Y=Dy_train, vectorizer='TFIDF', vec_name='TFIDF', 
                                           penalty=['l1', 'l2'], results_path=csv_path, retrain=True, W2V_model=None)
# Analysing best parameters
best_parameters = analyse_results(cv_results)
pprint.pprint(best_parameters)
# retraining the model with best parameters
model_path = 'saved_models/Assignment7/{0}_svm.pkl'.format('TFIDF')
calibrated_svm = retrain_with_best_params(Dx_train, Dy_train, best_parameters, 'TFIDF', model_path, None)

print('Retraining Vectorizer with Dx_train')
vectorizer_obj = get_vectorizer(W2V_model = None, train=Dx_train, vectorizer='TFIDF')

# plotting AUC ROC 
train_score, test_score = plot_AUC_ROC(calibrated_svm, vectorizer_obj, Dx_train, Dx_test, Dy_train, Dy_test)

# appending the data results
prettytable_data.append(['TFIDF', 'SVM', best_parameters['svm__penalty'], best_parameters['svm__alpha'], train_score, test_score])
# Out:
# Performing Hyperparameter Tuning...
#
# CV iteration : alpha=0.0001, penalty=l1, train_score=0.9481232756577104, test_score=0.9418747875303869
# CV iteration : alpha=0.0001, penalty=l1, train_score=0.9468720111155557, test_score=0.9369543507435567
# CV iteration : alpha=0.0001, penalty=l1, train_score=0.9474601374063486, test_score=0.9393991956461147
# C=0.0001, penalty=l1, train_score=0.9474851413932049, test_score=0.9394094446400194
# CV iteration : alpha=0.0001, penalty=l2, train_score=0.969747784014493, test_score=0.9543166795309809
# CV iteration : alpha=0.0001, penalty=l2, train_score=0.9695203277454942, test_score=0.951134470713222
# CV iteration : alpha=0.0001, penalty=l2, train_score=0.969064464079878, test_score=0.9537029589512209
# C=0.0001, penalty=l2, train_score=0.9694441919466218, test_score=0.9530513697318078
# CV iteration : alpha=0.0005, penalty=l1, train_score=0.8327512015759065, test_score=0.8289821905819796
# CV iteration : alpha=0.0005, penalty=l1, train_score=0.848203348108403, test_score=0.8410466934508647
# CV iteration : alpha=0.0005, penalty=l1, train_score=0.849481955675328, test_score=0.8491011635294217
# C=0.0005, penalty=l1, train_score=0.8434788351198792, test_score=0.8397100158540886
# CV iteration : alpha=0.0005, penalty=l2, train_score=0.9587488659262613, test_score=0.9476172827848274
# CV iteration : alpha=0.0005, penalty=l2, train_score=0.9584413641482536, test_score=0.9432176537744794
# CV iteration : alpha=0.0005, penalty=l2, train_score=0.9577834779601603, test_score=0.9465723606623503
# C=0.0005, penalty=l2, train_score=0.9583245693448917, test_score=0.9458024324072191
# CV iteration : alpha=0.001, penalty=l1, train_score=0.7238585582627888, test_score=0.7143307523806224
# CV iteration : alpha=0.001, penalty=l1, train_score=0.7800260946548535, test_score=0.7726483466680261
# CV iteration : alpha=0.001, penalty=l1, train_score=0.7821440073509761, test_score=0.7823146839235843
# C=0.001, penalty=l1, train_score=0.7620095534228728, test_score=0.7564312609907442
# CV iteration : alpha=0.001, penalty=l2, train_score=0.9581684404754705, test_score=0.9472994195885688
# CV iteration : alpha=0.001, penalty=l2, train_score=0.9580100035001665, test_score=0.9427144211629148
# CV iteration : alpha=0.001, penalty=l2, train_score=0.9573443880767396, test_score=0.9461126612106572
# C=0.001, penalty=l2, train_score=0.9578409440174589, test_score=0.945375500654047
# CV iteration : alpha=0.005, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.005, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.005, penalty=l1, train_score=0.5, test_score=0.5
# C=0.005, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.005, penalty=l2, train_score=0.9581717088108728, test_score=0.9472488490386598
# CV iteration : alpha=0.005, penalty=l2, train_score=0.9580163193374982, test_score=0.9426722760940771
# CV iteration : alpha=0.005, penalty=l2, train_score=0.9573467682309835, test_score=0.9461347308837491
# C=0.005, penalty=l2, train_score=0.9578449321264516, test_score=0.9453519520054954
# CV iteration : alpha=0.01, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.01, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.01, penalty=l1, train_score=0.5, test_score=0.5
# C=0.01, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.01, penalty=l2, train_score=0.95817711702263, test_score=0.9472243939473747
# CV iteration : alpha=0.01, penalty=l2, train_score=0.9580170988796584, test_score=0.9426469819873813
# CV iteration : alpha=0.01, penalty=l2, train_score=0.9573462007916137, test_score=0.9461579049239898
# C=0.01, penalty=l2, train_score=0.9578468055646341, test_score=0.945343093619582
# CV iteration : alpha=0.05, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.05, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.05, penalty=l1, train_score=0.5, test_score=0.5
# C=0.05, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.05, penalty=l2, train_score=0.9585491993415224, test_score=0.9479934354727731
# CV iteration : alpha=0.05, penalty=l2, train_score=0.9584363976034427, test_score=0.9433909060409075
# CV iteration : alpha=0.05, penalty=l2, train_score=0.9577706498561185, test_score=0.9467359130195485
# C=0.05, penalty=l2, train_score=0.9582520822670277, test_score=0.9460400848444097
# CV iteration : alpha=0.1, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.1, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.1, penalty=l1, train_score=0.5, test_score=0.5
# C=0.1, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.1, penalty=l2, train_score=0.7599435361492537, test_score=0.7594039055160546
# CV iteration : alpha=0.1, penalty=l2, train_score=0.7641328575514432, test_score=0.7594271065000944
# CV iteration : alpha=0.1, penalty=l2, train_score=0.7348696354635245, test_score=0.7114844447325027
# C=0.1, penalty=l2, train_score=0.752982009721407, test_score=0.743438485582884
# CV iteration : alpha=0.5, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.5, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.5, penalty=l1, train_score=0.5, test_score=0.5
# C=0.5, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=0.5, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=0.5, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=0.5, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=0.5, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=1, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=1, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=1, penalty=l1, train_score=0.5, test_score=0.5
# C=1, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=1, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=1, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=1, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=1, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=5, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=5, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=5, penalty=l1, train_score=0.5, test_score=0.5
# C=5, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=5, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=5, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=5, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=5, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=10, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=10, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=10, penalty=l1, train_score=0.5, test_score=0.5
# C=10, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=10, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=10, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=10, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=10, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=50, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=50, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=50, penalty=l1, train_score=0.5, test_score=0.5
# C=50, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=50, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=50, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=50, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=50, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=100, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=100, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=100, penalty=l1, train_score=0.5, test_score=0.5
# C=100, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=100, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=100, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=100, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=100, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=500, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=500, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=500, penalty=l1, train_score=0.5, test_score=0.5
# C=500, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=500, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=500, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=500, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=500, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=1000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=1000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=1000, penalty=l1, train_score=0.5, test_score=0.5
# C=1000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=1000, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=1000, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=1000, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=1000, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=5000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=5000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=5000, penalty=l1, train_score=0.5, test_score=0.5
# C=5000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=5000, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=5000, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=5000, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=5000, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# CV iteration : alpha=10000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=10000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=10000, penalty=l1, train_score=0.5, test_score=0.5
# C=10000, penalty=l1, train_score=0.5, test_score=0.5
# CV iteration : alpha=10000, penalty=l2, train_score=0.6061795141788142, test_score=0.609052396918655
# CV iteration : alpha=10000, penalty=l2, train_score=0.6061459276158843, test_score=0.6098257748289654
# CV iteration : alpha=10000, penalty=l2, train_score=0.6133674156407098, test_score=0.5890433826868239
# C=10000, penalty=l2, train_score=0.6085642858118028, test_score=0.6026405181448147
# {'svm__alpha': 0.0001, 'svm__penalty': 'l2'}
# Initializing Vectorizer
# Training Model....
# -- Epoch 1
# Norm: 30.28, NNZs: 5000, Bias: 0.863250, T: 61441, Avg. loss: 0.225348
# Total training time: 0.02 seconds.
# -- Epoch 2
# Norm: 29.38, NNZs: 5000, Bias: 0.822839, T: 122882, Avg. loss: 0.198347
# Total training time: 0.04 seconds.
# -- Epoch 3
# Norm: 29.06, NNZs: 5000, Bias: 0.807245, T: 184323, Avg. loss: 0.194295
# Total training time: 0.05 seconds.
# -- Epoch 4
# Norm: 28.89, NNZs: 5000, Bias: 0.809561, T: 245764, Avg. loss: 0.192263
# Total training time: 0.07 seconds.
# -- Epoch 5
# Norm: 28.83, NNZs: 5000, Bias: 0.808290, T: 307205, Avg. loss: 0.191664
# Total training time: 0.09 seconds.
# -- Epoch 6
# Norm: 28.76, NNZs: 5000, Bias: 0.809668, T: 368646, Avg. loss: 0.190802
# Total training time: 0.11 seconds.
# -- Epoch 7
# Norm: 28.73, NNZs: 5000, Bias: 0.807535, T: 430087, Avg. loss: 0.190498
# Total training time: 0.12 seconds.
# -- Epoch 8
# Norm: 28.73, NNZs: 5000, Bias: 0.810060, T: 491528, Avg. loss: 0.190136
# Total training time: 0.14 seconds.
# -- Epoch 9
# Norm: 28.69, NNZs: 5000, Bias: 0.804025, T: 552969, Avg. loss: 0.189810
# Total training time: 0.16 seconds.
# -- Epoch 10
# Norm: 28.69, NNZs: 5000, Bias: 0.801522, T: 614410, Avg. loss: 0.189633
# Total training time: 0.18 seconds.
# -- Epoch 11
# Norm: 28.67, NNZs: 5000, Bias: 0.803013, T: 675851, Avg. loss: 0.189461
# Total training time: 0.19 seconds.
# -- Epoch 12
# Norm: 28.68, NNZs: 5000, Bias: 0.796187, T: 737292, Avg. loss: 0.189330
# Total training time: 0.21 seconds.
# -- Epoch 13
# Norm: 28.68, NNZs: 5000, Bias: 0.801581, T: 798733, Avg. loss: 0.189189
# Total training time: 0.24 seconds.
# -- Epoch 14
# Norm: 28.67, NNZs: 5000, Bias: 0.802066, T: 860174, Avg. loss: 0.189065
# Total training time: 0.26 seconds.
# -- Epoch 15
# Norm: 28.66, NNZs: 5000, Bias: 0.805338, T: 921615, Avg. loss: 0.188836
# Total training time: 0.28 seconds.
# -- Epoch 16
# Norm: 28.65, NNZs: 5000, Bias: 0.802356, T: 983056, Avg. loss: 0.188834
# Total training time: 0.29 seconds.
# -- Epoch 17
# Norm: 28.66, NNZs: 5000, Bias: 0.798567, T: 1044497, Avg. loss: 0.188821
# Total training time: 0.31 seconds.
# -- Epoch 18
# Norm: 28.65, NNZs: 5000, Bias: 0.801083, T: 1105938, Avg. loss: 0.188750
# Total training time: 0.33 seconds.
# -- Epoch 19
# Norm: 28.66, NNZs: 5000, Bias: 0.801680, T: 1167379, Avg. loss: 0.188686
# Total training time: 0.34 seconds.
# -- Epoch 20
# Norm: 28.66, NNZs: 5000, Bias: 0.804041, T: 1228820, Avg. loss: 0.188594
# Total training time: 0.36 seconds.
# -- Epoch 21
# Norm: 28.65, NNZs: 5000, Bias: 0.802334, T: 1290261, Avg. loss: 0.188545
# Total training time: 0.38 seconds.
# -- Epoch 22
# Norm: 28.65, NNZs: 5000, Bias: 0.797338, T: 1351702, Avg. loss: 0.188539
# Total training time: 0.39 seconds.
# -- Epoch 23
# Norm: 28.65, NNZs: 5000, Bias: 0.801912, T: 1413143, Avg. loss: 0.188470
# Norm: 28.63, NNZs: 5000, Bias: 0.799574, T: 5222485, Avg. loss: 0.187800
# Total training time: 1.53 seconds.
# -- Epoch 86
# Norm: 28.63, NNZs: 5000, Bias: 0.799188, T: 5283926, Avg. loss: 0.187798
# Total training time: 1.55 seconds.
# -- Epoch 87
# Norm: 28.63, NNZs: 5000, Bias: 0.798496, T: 5345367, Avg. loss: 0.187804
# Total training time: 1.57 seconds.
# -- Epoch 88
# Norm: 28.63, NNZs: 5000, Bias: 0.799240, T: 5406808, Avg. loss: 0.187809
# Total training time: 1.59 seconds.
# -- Epoch 89
# Norm: 28.63, NNZs: 5000, Bias: 0.798577, T: 5468249, Avg. loss: 0.187805
# Total training time: 1.61 seconds.
# -- Epoch 90
# Norm: 28.63, NNZs: 5000, Bias: 0.799139, T: 5529690, Avg. loss: 0.187790
# Total training time: 1.63 seconds.
# -- Epoch 91
# Norm: 28.63, NNZs: 5000, Bias: 0.798831, T: 5591131, Avg. loss: 0.187796
# Total training time: 1.65 seconds.
# -- Epoch 92
# Norm: 28.63, NNZs: 5000, Bias: 0.798353, T: 5652572, Avg. loss: 0.187792
# Total training time: 1.67 seconds.
# -- Epoch 93
# Norm: 28.63, NNZs: 5000, Bias: 0.799619, T: 5714013, Avg. loss: 0.187784
# Total training time: 1.69 seconds.
# -- Epoch 94
# Norm: 28.63, NNZs: 5000, Bias: 0.798678, T: 5775454, Avg. loss: 0.187782
# Total training time: 1.71 seconds.
# -- Epoch 95
# Norm: 28.63, NNZs: 5000, Bias: 0.798800, T: 5836895, Avg. loss: 0.187781
# Total training time: 1.73 seconds.
# -- Epoch 96
# Norm: 28.63, NNZs: 5000, Bias: 0.798883, T: 5898336, Avg. loss: 0.187780
# Total training time: 1.76 seconds.
# -- Epoch 97
# Norm: 28.63, NNZs: 5000, Bias: 0.799068, T: 5959777, Avg. loss: 0.187778
# Total training time: 1.78 seconds.
# -- Epoch 98
# Norm: 28.63, NNZs: 5000, Bias: 0.798416, T: 6021218, Avg. loss: 0.187781
# Total training time: 1.79 seconds.
# -- Epoch 99
# Norm: 28.63, NNZs: 5000, Bias: 0.799322, T: 6082659, Avg. loss: 0.187765
# Total training time: 1.81 seconds.
# -- Epoch 100
# Norm: 28.63, NNZs: 5000, Bias: 0.798862, T: 6144100, Avg. loss: 0.187768
# Total training time: 1.83 seconds.
# -- Epoch 101
# Norm: 28.63, NNZs: 5000, Bias: 0.798972, T: 6205541, Avg. loss: 0.187768
# Total training time: 1.84 seconds.
# -- Epoch 102
# Norm: 28.63, NNZs: 5000, Bias: 0.799227, T: 6266982, Avg. loss: 0.187769
# Total training time: 1.86 seconds.
# -- Epoch 103
# Norm: 28.63, NNZs: 5000, Bias: 0.798669, T: 6328423, Avg. loss: 0.187762
# Total training time: 1.88 seconds.
# -- Epoch 104
# Norm: 28.63, NNZs: 5000, Bias: 0.799185, T: 6389864, Avg. loss: 0.187755
# Total training time: 1.89 seconds.
# -- Epoch 105
# Norm: 28.63, NNZs: 5000, Bias: 0.798469, T: 6451305, Avg. loss: 0.187763
# Total training time: 2.29 seconds.
# -- Epoch 127
# Norm: 28.63, NNZs: 5000, Bias: 0.798695, T: 7803007, Avg. loss: 0.187726
# Total training time: 2.30 seconds.
# -- Epoch 128
# Norm: 28.63, NNZs: 5000, Bias: 0.798325, T: 7864448, Avg. loss: 0.187724
# Total training time: 2.32 seconds.
# -- Epoch 129
# Norm: 28.63, NNZs: 5000, Bias: 0.799160, T: 7925889, Avg. loss: 0.187717
# Total training time: 2.34 seconds.
# -- Epoch 130
# Norm: 28.63, NNZs: 5000, Bias: 0.798595, T: 7987330, Avg. loss: 0.187725
# Total training time: 2.36 seconds.
# -- Epoch 131
# Norm: 28.63, NNZs: 5000, Bias: 0.798571, T: 8048771, Avg. loss: 0.187723
# Total training time: 2.37 seconds.
# -- Epoch 132
# Norm: 28.63, NNZs: 5000, Bias: 0.798597, T: 8110212, Avg. loss: 0.187717
# Total training time: 2.40 seconds.
# -- Epoch 133
# Norm: 28.63, NNZs: 5000, Bias: 0.798989, T: 8171653, Avg. loss: 0.187703
# Total training time: 2.42 seconds.
# -- Epoch 134
# Norm: 28.63, NNZs: 5000, Bias: 0.798805, T: 8233094, Avg. loss: 0.187710
# Total training time: 2.44 seconds.
# -- Epoch 135
# Norm: 28.63, NNZs: 5000, Bias: 0.798635, T: 8294535, Avg. loss: 0.187715
# Total training time: 2.45 seconds.
# -- Epoch 136
# Norm: 28.63, NNZs: 5000, Bias: 0.798743, T: 8355976, Avg. loss: 0.187712
# Total training time: 2.47 seconds.
# -- Epoch 137
# Norm: 28.63, NNZs: 5000, Bias: 0.799100, T: 8417417, Avg. loss: 0.187706
# Total training time: 2.49 seconds.
# -- Epoch 138
# Norm: 28.63, NNZs: 5000, Bias: 0.798460, T: 8478858, Avg. loss: 0.187709
# Total training time: 2.50 seconds.
# -- Epoch 139
# Norm: 28.63, NNZs: 5000, Bias: 0.798871, T: 8540299, Avg. loss: 0.187698
# Total training time: 2.52 seconds.
# -- Epoch 140
# Norm: 28.63, NNZs: 5000, Bias: 0.798776, T: 8601740, Avg. loss: 0.187706
# Total training time: 2.54 seconds.
# -- Epoch 141
# Norm: 28.63, NNZs: 5000, Bias: 0.798545, T: 8663181, Avg. loss: 0.187710
# Total training time: 2.55 seconds.
# -- Epoch 142
# Norm: 28.63, NNZs: 5000, Bias: 0.799152, T: 8724622, Avg. loss: 0.187702
# Total training time: 2.57 seconds.
# -- Epoch 143
# Norm: 28.63, NNZs: 5000, Bias: 0.798819, T: 8786063, Avg. loss: 0.187706
# Total training time: 2.59 seconds.
# -- Epoch 144
# Norm: 28.63, NNZs: 5000, Bias: 0.798535, T: 8847504, Avg. loss: 0.187705
# Total training time: 2.61 seconds.
# -- Epoch 145
# Norm: 28.63, NNZs: 5000, Bias: 0.799243, T: 8908945, Avg. loss: 0.187703
# Total training time: 2.63 seconds.
# -- Epoch 146
# Norm: 28.63, NNZs: 5000, Bias: 0.799105, T: 8970386, Avg. loss: 0.187696
# Total training time: 2.65 seconds.
# -- Epoch 147
# Norm: 28.63, NNZs: 5000, Bias: 0.799235, T: 9031827, Avg. loss: 0.187692
# Total training time: 2.67 seconds.
# -- Epoch 148
# Norm: 28.63, NNZs: 5000, Bias: 0.798384, T: 9093268, Avg. loss: 0.187699
# Total training time: 2.68 seconds.
# -- Epoch 149
# Norm: 28.63, NNZs: 5000, Bias: 0.798823, T: 9154709, Avg. loss: 0.187701
# Total training time: 2.70 seconds.
# -- Epoch 150
# Norm: 28.63, NNZs: 5000, Bias: 0.798584, T: 9216150, Avg. loss: 0.187697
# Total training time: 2.72 seconds.
# -- Epoch 151
# Norm: 28.63, NNZs: 5000, Bias: 0.798552, T: 9277591, Avg. loss: 0.187697
# Total training time: 2.73 seconds.
# -- Epoch 152
# Norm: 28.63, NNZs: 5000, Bias: 0.798392, T: 9339032, Avg. loss: 0.187696
# Total training time: 2.75 seconds.
# -- Epoch 153
# Norm: 28.63, NNZs: 5000, Bias: 0.798149, T: 9400473, Avg. loss: 0.187699
# Total training time: 2.77 seconds.
# -- Epoch 154
# Norm: 28.63, NNZs: 5000, Bias: 0.798048, T: 9461914, Avg. loss: 0.187696
# Total training time: 2.79 seconds.
# -- Epoch 155
# Norm: 28.63, NNZs: 5000, Bias: 0.798859, T: 9523355, Avg. loss: 0.187692
# Total training time: 2.81 seconds.
# -- Epoch 156
# Norm: 28.63, NNZs: 5000, Bias: 0.798856, T: 9584796, Avg. loss: 0.187693
# Total training time: 2.83 seconds.
# -- Epoch 157
# Norm: 28.63, NNZs: 5000, Bias: 0.798979, T: 9646237, Avg. loss: 0.187691
# Total training time: 2.85 seconds.
# -- Epoch 158
# Norm: 28.63, NNZs: 5000, Bias: 0.798739, T: 9707678, Avg. loss: 0.187691
# Total training time: 2.87 seconds.
# -- Epoch 159
# Norm: 28.63, NNZs: 5000, Bias: 0.798441, T: 9769119, Avg. loss: 0.187689
# Total training time: 2.88 seconds.
# -- Epoch 160
# Norm: 28.63, NNZs: 5000, Bias: 0.798442, T: 9830560, Avg. loss: 0.187691
# Total training time: 2.90 seconds.
# -- Epoch 161
# Norm: 28.63, NNZs: 5000, Bias: 0.798675, T: 9892001, Avg. loss: 0.187690
# Total training time: 2.91 seconds.
# -- Epoch 162
# Norm: 28.63, NNZs: 5000, Bias: 0.798765, T: 9953442, Avg. loss: 0.187685
# Total training time: 2.93 seconds.
# -- Epoch 163
# Norm: 28.63, NNZs: 5000, Bias: 0.798923, T: 10014883, Avg. loss: 0.187685
# Total training time: 2.95 seconds.
# -- Epoch 164
# Norm: 28.63, NNZs: 5000, Bias: 0.799030, T: 10076324, Avg. loss: 0.187684
# Total training time: 2.96 seconds.
# -- Epoch 165
# Norm: 28.63, NNZs: 5000, Bias: 0.798346, T: 10137765, Avg. loss: 0.187690
# Total training time: 2.98 seconds.
# -- Epoch 166
# Norm: 28.63, NNZs: 5000, Bias: 0.798661, T: 10199206, Avg. loss: 0.187684
# Total training time: 3.00 seconds.
# -- Epoch 167
# Norm: 28.63, NNZs: 5000, Bias: 0.798913, T: 10260647, Avg. loss: 0.187683
# Total training time: 3.02 seconds.
# -- Epoch 168
# Norm: 28.63, NNZs: 5000, Bias: 0.798650, T: 10322088, Avg. loss: 0.187680
# Total training time: 3.04 seconds.
# -- Epoch 169
# Norm: 28.63, NNZs: 5000, Bias: 0.799005, T: 10383529, Avg. loss: 0.187675
# Total training time: 3.06 seconds.
# -- Epoch 170
# Norm: 28.63, NNZs: 5000, Bias: 0.798083, T: 10444970, Avg. loss: 0.187678
# Total training time: 3.08 seconds.
# -- Epoch 171
# Norm: 28.63, NNZs: 5000, Bias: 0.798428, T: 10506411, Avg. loss: 0.187681
# Total training time: 3.09 seconds.
# -- Epoch 172
# Norm: 28.63, NNZs: 5000, Bias: 0.798542, T: 10567852, Avg. loss: 0.187679
# Total training time: 3.11 seconds.
# -- Epoch 173
# Norm: 28.63, NNZs: 5000, Bias: 0.798448, T: 10629293, Avg. loss: 0.187677
# Total training time: 3.13 seconds.
# -- Epoch 174
# Norm: 28.63, NNZs: 5000, Bias: 0.798374, T: 10690734, Avg. loss: 0.187679
# Total training time: 3.15 seconds.
# -- Epoch 175
# Norm: 28.63, NNZs: 5000, Bias: 0.798589, T: 10752175, Avg. loss: 0.187677
# Total training time: 3.16 seconds.
# -- Epoch 176
# Norm: 28.63, NNZs: 5000, Bias: 0.798792, T: 10813616, Avg. loss: 0.187674
# Total training time: 3.18 seconds.
# -- Epoch 177
# Norm: 28.63, NNZs: 5000, Bias: 0.798607, T: 10875057, Avg. loss: 0.187676
# Total training time: 3.19 seconds.
# -- Epoch 178
# Norm: 28.63, NNZs: 5000, Bias: 0.798323, T: 10936498, Avg. loss: 0.187673
# Total training time: 3.21 seconds.
# -- Epoch 179
# Norm: 28.63, NNZs: 5000, Bias: 0.798543, T: 10997939, Avg. loss: 0.187673
# Total training time: 3.23 seconds.
# -- Epoch 180
# Norm: 28.63, NNZs: 5000, Bias: 0.798705, T: 11059380, Avg. loss: 0.187671
# Total training time: 3.25 seconds.
# -- Epoch 181
# Norm: 28.63, NNZs: 5000, Bias: 0.798713, T: 11120821, Avg. loss: 0.187670
# Total training time: 3.28 seconds.
# -- Epoch 182
# Norm: 28.63, NNZs: 5000, Bias: 0.798704, T: 11182262, Avg. loss: 0.187668
# Total training time: 3.30 seconds.
# -- Epoch 183
# Norm: 28.63, NNZs: 5000, Bias: 0.798783, T: 11243703, Avg. loss: 0.187666
# Total training time: 3.32 seconds.
# -- Epoch 184
# Norm: 28.63, NNZs: 5000, Bias: 0.798561, T: 11305144, Avg. loss: 0.187671
# Total training time: 3.34 seconds.
# -- Epoch 185
# Norm: 28.63, NNZs: 5000, Bias: 0.798877, T: 11366585, Avg. loss: 0.187664
# Total training time: 3.35 seconds.
# -- Epoch 186
# Norm: 28.63, NNZs: 5000, Bias: 0.798901, T: 11428026, Avg. loss: 0.187667
# Total training time: 3.37 seconds.
# -- Epoch 187
# Norm: 28.63, NNZs: 5000, Bias: 0.798768, T: 11489467, Avg. loss: 0.187667
# Total training time: 3.39 seconds.
# -- Epoch 188
# Norm: 28.63, NNZs: 5000, Bias: 0.798550, T: 11550908, Avg. loss: 0.187667
# Total training time: 3.40 seconds.
# -- Epoch 189
# Norm: 28.63, NNZs: 5000, Bias: 0.798541, T: 11612349, Avg. loss: 0.187671
# Total training time: 3.42 seconds.
# -- Epoch 190
# Norm: 28.63, NNZs: 5000, Bias: 0.798344, T: 11673790, Avg. loss: 0.187667
# Total training time: 3.44 seconds.
# -- Epoch 191
# Norm: 28.63, NNZs: 5000, Bias: 0.798677, T: 11735231, Avg. loss: 0.187664
# Total training time: 3.46 seconds.
# -- Epoch 192
# Norm: 28.63, NNZs: 5000, Bias: 0.798668, T: 11796672, Avg. loss: 0.187668
# Total training time: 3.48 seconds.
# -- Epoch 193
# Norm: 28.63, NNZs: 5000, Bias: 0.798481, T: 11858113, Avg. loss: 0.187665
# Total training time: 3.50 seconds.
# -- Epoch 194
# Norm: 28.63, NNZs: 5000, Bias: 0.798415, T: 11919554, Avg. loss: 0.187662
# Total training time: 3.52 seconds.
# -- Epoch 195
# Norm: 28.63, NNZs: 5000, Bias: 0.798374, T: 11980995, Avg. loss: 0.187664
# Total training time: 3.53 seconds.
# -- Epoch 196
# Norm: 28.63, NNZs: 5000, Bias: 0.798764, T: 12042436, Avg. loss: 0.187660
# Total training time: 3.55 seconds.
# -- Epoch 197
# Norm: 28.63, NNZs: 5000, Bias: 0.798383, T: 12103877, Avg. loss: 0.187667
# Total training time: 3.57 seconds.
# -- Epoch 198
# Norm: 28.63, NNZs: 5000, Bias: 0.798326, T: 12165318, Avg. loss: 0.187661
# Total training time: 3.58 seconds.
# -- Epoch 199
# Norm: 28.63, NNZs: 5000, Bias: 0.798392, T: 12226759, Avg. loss: 0.187657
# Total training time: 3.60 seconds.
# -- Epoch 200
# Norm: 28.63, NNZs: 5000, Bias: 0.798604, T: 12288200, Avg. loss: 0.187660
# Total training time: 3.62 seconds.
# -- Epoch 201
# Norm: 28.63, NNZs: 5000, Bias: 0.798304, T: 12349641, Avg. loss: 0.187659
# Total training time: 3.63 seconds.
# -- Epoch 202
# Norm: 28.63, NNZs: 5000, Bias: 0.798361, T: 12411082, Avg. loss: 0.187654
# Total training time: 3.65 seconds.
# -- Epoch 203
# Norm: 28.63, NNZs: 5000, Bias: 0.798377, T: 12472523, Avg. loss: 0.187664
# Total training time: 3.67 seconds.
# -- Epoch 204
# Norm: 28.63, NNZs: 5000, Bias: 0.798282, T: 12533964, Avg. loss: 0.187658
# Total training time: 3.69 seconds.
# -- Epoch 205
# Norm: 28.63, NNZs: 5000, Bias: 0.798370, T: 12595405, Avg. loss: 0.187659
# Total training time: 3.71 seconds.
# -- Epoch 206
# Norm: 28.63, NNZs: 5000, Bias: 0.798671, T: 12656846, Avg. loss: 0.187660
# Total training time: 3.73 seconds.
# -- Epoch 207
# Norm: 28.63, NNZs: 5000, Bias: 0.798733, T: 12718287, Avg. loss: 0.187656
# Total training time: 3.75 seconds.
# -- Epoch 208
# Norm: 28.63, NNZs: 5000, Bias: 0.798560, T: 12779728, Avg. loss: 0.187658
# Total training time: 3.76 seconds.
# Total training time: 4.86 seconds.
# -- Epoch 271
# Norm: 28.63, NNZs: 5000, Bias: 0.798347, T: 16650511, Avg. loss: 0.187633
# Total training time: 4.88 seconds.
# -- Epoch 272
# Norm: 28.63, NNZs: 5000, Bias: 0.798269, T: 16711952, Avg. loss: 0.187634
# Total training time: 4.89 seconds.
# -- Epoch 273
# Norm: 28.63, NNZs: 5000, Bias: 0.798687, T: 16773393, Avg. loss: 0.187629
# Total training time: 4.91 seconds.
# -- Epoch 274
# Norm: 28.63, NNZs: 5000, Bias: 0.798722, T: 16834834, Avg. loss: 0.187629
# Total training time: 4.94 seconds.
# -- Epoch 275
# Norm: 28.63, NNZs: 5000, Bias: 0.798342, T: 16896275, Avg. loss: 0.187633
# Total training time: 4.96 seconds.
# -- Epoch 276
# Norm: 28.63, NNZs: 5000, Bias: 0.798294, T: 16957716, Avg. loss: 0.187634
# Total training time: 4.98 seconds.
# -- Epoch 277
# Norm: 28.63, NNZs: 5000, Bias: 0.798395, T: 17019157, Avg. loss: 0.187632
# Total training time: 5.00 seconds.
# -- Epoch 278
# Norm: 28.63, NNZs: 5000, Bias: 0.798500, T: 17080598, Avg. loss: 0.187629
# Total training time: 5.02 seconds.
# -- Epoch 279
# Norm: 28.63, NNZs: 5000, Bias: 0.798190, T: 17142039, Avg. loss: 0.187632
# Total training time: 5.04 seconds.
# -- Epoch 280
# Norm: 28.63, NNZs: 5000, Bias: 0.798243, T: 17203480, Avg. loss: 0.187629
# Total training time: 5.06 seconds.
# -- Epoch 281
# Norm: 28.63, NNZs: 5000, Bias: 0.798157, T: 17264921, Avg. loss: 0.187630
# Total training time: 5.08 seconds.
# -- Epoch 282
# Norm: 28.63, NNZs: 5000, Bias: 0.798458, T: 17326362, Avg. loss: 0.187628
# Total training time: 5.10 seconds.
# -- Epoch 283
# Norm: 28.63, NNZs: 5000, Bias: 0.798532, T: 17387803, Avg. loss: 0.187629
# Total training time: 5.12 seconds.
# -- Epoch 284
# Norm: 28.63, NNZs: 5000, Bias: 0.798268, T: 17449244, Avg. loss: 0.187628
# Total training time: 5.13 seconds.
# -- Epoch 285
# Norm: 28.63, NNZs: 5000, Bias: 0.798234, T: 17510685, Avg. loss: 0.187629
# Total training time: 5.15 seconds.
# -- Epoch 286
# Norm: 28.63, NNZs: 5000, Bias: 0.798656, T: 17572126, Avg. loss: 0.187625
# Total training time: 5.17 seconds.
# -- Epoch 287
# Norm: 28.63, NNZs: 5000, Bias: 0.798274, T: 17633567, Avg. loss: 0.187629
# Total training time: 5.20 seconds.
# -- Epoch 288
# Norm: 28.63, NNZs: 5000, Bias: 0.798376, T: 17695008, Avg. loss: 0.187628
# Total training time: 5.21 seconds.
# -- Epoch 289
# Norm: 28.63, NNZs: 5000, Bias: 0.798196, T: 17756449, Avg. loss: 0.187628
# Total training time: 5.23 seconds.
# -- Epoch 290
# Norm: 28.63, NNZs: 5000, Bias: 0.798326, T: 17817890, Avg. loss: 0.187627
# Total training time: 5.25 seconds.
# -- Epoch 291
# Norm: 28.63, NNZs: 5000, Bias: 0.798320, T: 17879331, Avg. loss: 0.187625
# Total training time: 5.26 seconds.
# -- Epoch 292
# Norm: 28.63, NNZs: 5000, Bias: 0.798293, T: 17940772, Avg. loss: 0.187631
# Total training time: 5.28 seconds.
# -- Epoch 293
# Norm: 28.63, NNZs: 5000, Bias: 0.798315, T: 18002213, Avg. loss: 0.187628
# Total training time: 5.30 seconds.
# -- Epoch 294
# Norm: 28.63, NNZs: 5000, Bias: 0.798603, T: 18063654, Avg. loss: 0.187625
# Total training time: 5.31 seconds.
# -- Epoch 295
# Norm: 28.63, NNZs: 5000, Bias: 0.798647, T: 18125095, Avg. loss: 0.187624
# Total training time: 5.33 seconds.
# -- Epoch 296
# Norm: 28.63, NNZs: 5000, Bias: 0.798399, T: 18186536, Avg. loss: 0.187625
# Total training time: 5.35 seconds.
# -- Epoch 297
# Norm: 28.63, NNZs: 5000, Bias: 0.798322, T: 18247977, Avg. loss: 0.187625
# Total training time: 5.37 seconds.
# -- Epoch 298
# Norm: 28.63, NNZs: 5000, Bias: 0.798442, T: 18309418, Avg. loss: 0.187626
# Total training time: 5.38 seconds.
# -- Epoch 299
# Norm: 28.63, NNZs: 5000, Bias: 0.798485, T: 18370859, Avg. loss: 0.187623
# Total training time: 5.41 seconds.
# -- Epoch 300
# Norm: 28.63, NNZs: 5000, Bias: 0.798290, T: 18432300, Avg. loss: 0.187624
# Total training time: 5.43 seconds.
# -- Epoch 301
# Norm: 28.63, NNZs: 5000, Bias: 0.798268, T: 18493741, Avg. loss: 0.187625
# Total training time: 5.44 seconds.
# -- Epoch 302
# Norm: 28.63, NNZs: 5000, Bias: 0.798398, T: 18555182, Avg. loss: 0.187625
# ...
# Total training time: 16.16 seconds.
# -- Epoch 873
# Norm: 28.63, NNZs: 5000, Bias: 0.798193, T: 53637993, Avg. loss: 0.187575
# Total training time: 16.19 seconds.
# -- Epoch 874
# Norm: 28.63, NNZs: 5000, Bias: 0.798152, T: 53699434, Avg. loss: 0.187576
# Total training time: 16.20 seconds.
# -- Epoch 875
# Norm: 28.63, NNZs: 5000, Bias: 0.798178, T: 53760875, Avg. loss: 0.187575
# Total training time: 16.22 seconds.
# -- Epoch 876
# Norm: 28.63, NNZs: 5000, Bias: 0.798228, T: 53822316, Avg. loss: 0.187575
# Total training time: 16.24 seconds.
# -- Epoch 877
# Norm: 28.63, NNZs: 5000, Bias: 0.798182, T: 53883757, Avg. loss: 0.187575
# Total training time: 16.26 seconds.
# -- Epoch 878
# Norm: 28.63, NNZs: 5000, Bias: 0.798269, T: 53945198, Avg. loss: 0.187576
# Total training time: 16.28 seconds.
# -- Epoch 879
# Norm: 28.63, NNZs: 5000, Bias: 0.798167, T: 54006639, Avg. loss: 0.187576
# Total training time: 16.30 seconds.
# -- Epoch 880
# Norm: 28.63, NNZs: 5000, Bias: 0.798145, T: 54068080, Avg. loss: 0.187575
# Total training time: 16.32 seconds.
# -- Epoch 881
# Norm: 28.63, NNZs: 5000, Bias: 0.798191, T: 54129521, Avg. loss: 0.187575
# Total training time: 16.33 seconds.
# -- Epoch 882
# Norm: 28.63, NNZs: 5000, Bias: 0.798084, T: 54190962, Avg. loss: 0.187575
# Total training time: 16.35 seconds.
# -- Epoch 883
# Norm: 28.63, NNZs: 5000, Bias: 0.798207, T: 54252403, Avg. loss: 0.187576
# Total training time: 16.37 seconds.
# -- Epoch 884
# Norm: 28.63, NNZs: 5000, Bias: 0.798137, T: 54313844, Avg. loss: 0.187576
# Total training time: 16.39 seconds.
# -- Epoch 885
# Norm: 28.63, NNZs: 5000, Bias: 0.798216, T: 54375285, Avg. loss: 0.187575
# Total training time: 16.41 seconds.
# -- Epoch 886
# Norm: 28.63, NNZs: 5000, Bias: 0.798180, T: 54436726, Avg. loss: 0.187576
# Total training time: 16.43 seconds.
# -- Epoch 887
# Norm: 28.63, NNZs: 5000, Bias: 0.798246, T: 54498167, Avg. loss: 0.187575
# Total training time: 16.45 seconds.
# -- Epoch 888
# Norm: 28.63, NNZs: 5000, Bias: 0.798182, T: 54559608, Avg. loss: 0.187575
# Total training time: 16.47 seconds.
# -- Epoch 889
# Norm: 28.63, NNZs: 5000, Bias: 0.798172, T: 54621049, Avg. loss: 0.187576
# Total training time: 16.49 seconds.
# -- Epoch 890
# Norm: 28.63, NNZs: 5000, Bias: 0.798150, T: 54682490, Avg. loss: 0.187575
# Total training time: 16.50 seconds.
# -- Epoch 891
# Norm: 28.63, NNZs: 5000, Bias: 0.798247, T: 54743931, Avg. loss: 0.187576
# Total training time: 16.52 seconds.
# -- Epoch 892
# Norm: 28.63, NNZs: 5000, Bias: 0.798240, T: 54805372, Avg. loss: 0.187575
# Total training time: 16.54 seconds.
# -- Epoch 893
# Norm: 28.63, NNZs: 5000, Bias: 0.798129, T: 54866813, Avg. loss: 0.187575
# Total training time: 16.56 seconds.
# -- Epoch 894
# Norm: 28.63, NNZs: 5000, Bias: 0.798191, T: 54928254, Avg. loss: 0.187575
# Total training time: 16.57 seconds.
# -- Epoch 895
# Norm: 28.63, NNZs: 5000, Bias: 0.798158, T: 54989695, Avg. loss: 0.187576
# Total training time: 16.59 seconds.
# -- Epoch 896
# Norm: 28.63, NNZs: 5000, Bias: 0.798096, T: 55051136, Avg. loss: 0.187576
# Total training time: 16.61 seconds.
# -- Epoch 897
# Norm: 28.63, NNZs: 5000, Bias: 0.798178, T: 55112577, Avg. loss: 0.187575
# Total training time: 16.63 seconds.
# -- Epoch 898
# Norm: 28.63, NNZs: 5000, Bias: 0.798214, T: 55174018, Avg. loss: 0.187576
# Total training time: 16.65 seconds.
# -- Epoch 899
# Norm: 28.63, NNZs: 5000, Bias: 0.798162, T: 55235459, Avg. loss: 0.187575
# Total training time: 16.67 seconds.
# -- Epoch 900
# Norm: 28.63, NNZs: 5000, Bias: 0.798194, T: 55296900, Avg. loss: 0.187575
# Total training time: 16.69 seconds.
# -- Epoch 901
# Norm: 28.63, NNZs: 5000, Bias: 0.798225, T: 55358341, Avg. loss: 0.187575
# Total training time: 16.71 seconds.
# -- Epoch 902
# Norm: 28.63, NNZs: 5000, Bias: 0.798227, T: 55419782, Avg. loss: 0.187575
# Total training time: 16.72 seconds.
# -- Epoch 903
# Norm: 28.63, NNZs: 5000, Bias: 0.798250, T: 55481223, Avg. loss: 0.187575
# Total training time: 16.74 seconds.
# -- Epoch 904
# Norm: 28.63, NNZs: 5000, Bias: 0.798205, T: 55542664, Avg. loss: 0.187575
# Total training time: 16.76 seconds.
# -- Epoch 905
# Norm: 28.63, NNZs: 5000, Bias: 0.798261, T: 55604105, Avg. loss: 0.187575
# Total training time: 16.78 seconds.
# -- Epoch 906
# Norm: 28.63, NNZs: 5000, Bias: 0.798226, T: 55665546, Avg. loss: 0.187575
# Total training time: 16.81 seconds.
# -- Epoch 907
# Norm: 28.63, NNZs: 5000, Bias: 0.798181, T: 55726987, Avg. loss: 0.187575
# Total training time: 16.82 seconds.
# -- Epoch 908
# Norm: 28.63, NNZs: 5000, Bias: 0.798190, T: 55788428, Avg. loss: 0.187575
# Total training time: 16.84 seconds.
# -- Epoch 909
# Norm: 28.63, NNZs: 5000, Bias: 0.798258, T: 55849869, Avg. loss: 0.187575
# Total training time: 16.86 seconds.
# -- Epoch 910
# Norm: 28.63, NNZs: 5000, Bias: 0.798235, T: 55911310, Avg. loss: 0.187574
# Total training time: 16.88 seconds.
# -- Epoch 911
# Norm: 28.63, NNZs: 5000, Bias: 0.798197, T: 55972751, Avg. loss: 0.187575
# Total training time: 16.90 seconds.
# -- Epoch 912
# Norm: 28.63, NNZs: 5000, Bias: 0.798119, T: 56034192, Avg. loss: 0.187575
# Total training time: 16.92 seconds.
# -- Epoch 913
# Norm: 28.63, NNZs: 5000, Bias: 0.798212, T: 56095633, Avg. loss: 0.187575
# Total training time: 16.94 seconds.
# -- Epoch 914
# Norm: 28.63, NNZs: 5000, Bias: 0.798221, T: 56157074, Avg. loss: 0.187575
# Total training time: 16.95 seconds.
# -- Epoch 915
# Norm: 28.63, NNZs: 5000, Bias: 0.798212, T: 56218515, Avg. loss: 0.187574
# Total training time: 16.97 seconds.
# -- Epoch 916
# Norm: 28.63, NNZs: 5000, Bias: 0.798180, T: 56279956, Avg. loss: 0.187573
# Total training time: 16.99 seconds.
# -- Epoch 917
# Norm: 28.63, NNZs: 5000, Bias: 0.798187, T: 56341397, Avg. loss: 0.187574
# Total training time: 17.01 seconds.
# -- Epoch 918
# Norm: 28.63, NNZs: 5000, Bias: 0.798201, T: 56402838, Avg. loss: 0.187575
# Total training time: 17.03 seconds.
# -- Epoch 919
# Norm: 28.63, NNZs: 5000, Bias: 0.798162, T: 56464279, Avg. loss: 0.187575
# Total training time: 17.05 seconds.
# -- Epoch 920
# Norm: 28.63, NNZs: 5000, Bias: 0.798231, T: 56525720, Avg. loss: 0.187575
# Total training time: 17.07 seconds.
# -- Epoch 921
# Norm: 28.63, NNZs: 5000, Bias: 0.798210, T: 56587161, Avg. loss: 0.187574
# Total training time: 17.09 seconds.
# -- Epoch 922
# Norm: 28.63, NNZs: 5000, Bias: 0.798109, T: 56648602, Avg. loss: 0.187575
# Total training time: 17.11 seconds.
# -- Epoch 923
# Norm: 28.63, NNZs: 5000, Bias: 0.798203, T: 56710043, Avg. loss: 0.187573
# Total training time: 17.13 seconds.
# -- Epoch 924
# Norm: 28.63, NNZs: 5000, Bias: 0.798178, T: 56771484, Avg. loss: 0.187575
# Total training time: 17.14 seconds.
# -- Epoch 925
# Norm: 28.63, NNZs: 5000, Bias: 0.798241, T: 56832925, Avg. loss: 0.187574
# Total training time: 17.16 seconds.
# -- Epoch 926
# Norm: 28.63, NNZs: 5000, Bias: 0.798130, T: 56894366, Avg. loss: 0.187575
# Total training time: 17.18 seconds.
# -- Epoch 927
# Norm: 28.63, NNZs: 5000, Bias: 0.798192, T: 56955807, Avg. loss: 0.187575
# Total training time: 17.20 seconds.
# -- Epoch 928
# Norm: 28.63, NNZs: 5000, Bias: 0.798162, T: 57017248, Avg. loss: 0.187575
# Total training time: 17.21 seconds.
# -- Epoch 929
# Norm: 28.63, NNZs: 5000, Bias: 0.798285, T: 57078689, Avg. loss: 0.187574
# Total training time: 17.23 seconds.
# -- Epoch 930
# Norm: 28.63, NNZs: 5000, Bias: 0.798216, T: 57140130, Avg. loss: 0.187574
# Total training time: 17.25 seconds.
# -- Epoch 931
# Norm: 28.63, NNZs: 5000, Bias: 0.798085, T: 57201571, Avg. loss: 0.187575
# Total training time: 17.27 seconds.
# -- Epoch 932
# Norm: 28.63, NNZs: 5000, Bias: 0.798139, T: 57263012, Avg. loss: 0.187575
# Total training time: 17.30 seconds.
# -- Epoch 933
# Norm: 28.63, NNZs: 5000, Bias: 0.798125, T: 57324453, Avg. loss: 0.187575
# Total training time: 17.31 seconds.
# -- Epoch 934
# Norm: 28.63, NNZs: 5000, Bias: 0.798183, T: 57385894, Avg. loss: 0.187574
# Total training time: 17.33 seconds.
# -- Epoch 935
# Norm: 28.63, NNZs: 5000, Bias: 0.798138, T: 57447335, Avg. loss: 0.187575
# Total training time: 17.35 seconds.
# -- Epoch 936
# Norm: 28.63, NNZs: 5000, Bias: 0.798185, T: 57508776, Avg. loss: 0.187574
# Total training time: 17.37 seconds.
# -- Epoch 937
# Norm: 28.63, NNZs: 5000, Bias: 0.798190, T: 57570217, Avg. loss: 0.187575
# Total training time: 17.38 seconds.
# -- Epoch 938
# Norm: 28.63, NNZs: 5000, Bias: 0.798231, T: 57631658, Avg. loss: 0.187574
# Total training time: 17.40 seconds.
# -- Epoch 939
# Norm: 28.63, NNZs: 5000, Bias: 0.798211, T: 57693099, Avg. loss: 0.187574
# Total training time: 17.42 seconds.
# -- Epoch 940
# Norm: 28.63, NNZs: 5000, Bias: 0.798240, T: 57754540, Avg. loss: 0.187573
# Total training time: 17.44 seconds.
# -- Epoch 941
# Norm: 28.63, NNZs: 5000, Bias: 0.798188, T: 57815981, Avg. loss: 0.187574
# Total training time: 17.46 seconds.
# -- Epoch 942
# Norm: 28.63, NNZs: 5000, Bias: 0.798245, T: 57877422, Avg. loss: 0.187574
# Total training time: 17.48 seconds.
# -- Epoch 943
# Norm: 28.63, NNZs: 5000, Bias: 0.798214, T: 57938863, Avg. loss: 0.187574
# Total training time: 17.50 seconds.
# -- Epoch 944
# Norm: 28.63, NNZs: 5000, Bias: 0.798103, T: 58000304, Avg. loss: 0.187574
# Total training time: 17.52 seconds.
# -- Epoch 945
# Norm: 28.63, NNZs: 5000, Bias: 0.798236, T: 58061745, Avg. loss: 0.187574
# Total training time: 17.54 seconds.
# -- Epoch 946
# Norm: 28.63, NNZs: 5000, Bias: 0.798148, T: 58123186, Avg. loss: 0.187574
# Total training time: 17.55 seconds.
# -- Epoch 947
# Norm: 28.63, NNZs: 5000, Bias: 0.798227, T: 58184627, Avg. loss: 0.187574
# Total training time: 17.57 seconds.
# -- Epoch 948
# Norm: 28.63, NNZs: 5000, Bias: 0.798207, T: 58246068, Avg. loss: 0.187574
# Total training time: 17.59 seconds.
# -- Epoch 949
# Norm: 28.63, NNZs: 5000, Bias: 0.798325, T: 58307509, Avg. loss: 0.187573
# Total training time: 17.61 seconds.
# -- Epoch 950
# Norm: 28.63, NNZs: 5000, Bias: 0.798160, T: 58368950, Avg. loss: 0.187575
# Total training time: 17.63 seconds.
# -- Epoch 951
# Norm: 28.63, NNZs: 5000, Bias: 0.798200, T: 58430391, Avg. loss: 0.187574
# Total training time: 17.65 seconds.
# -- Epoch 952
# Norm: 28.63, NNZs: 5000, Bias: 0.798191, T: 58491832, Avg. loss: 0.187574
# Total training time: 17.66 seconds.
# -- Epoch 953
# Norm: 28.63, NNZs: 5000, Bias: 0.798169, T: 58553273, Avg. loss: 0.187574
# Total training time: 17.68 seconds.
# -- Epoch 954
# Norm: 28.63, NNZs: 5000, Bias: 0.798189, T: 58614714, Avg. loss: 0.187574
# Total training time: 17.71 seconds.
# -- Epoch 955
# Norm: 28.63, NNZs: 5000, Bias: 0.798189, T: 58676155, Avg. loss: 0.187573
# Total training time: 17.73 seconds.
# -- Epoch 956
# Norm: 28.63, NNZs: 5000, Bias: 0.798205, T: 58737596, Avg. loss: 0.187574
# Total training time: 17.74 seconds.
# -- Epoch 957
# Norm: 28.63, NNZs: 5000, Bias: 0.798249, T: 58799037, Avg. loss: 0.187573
# Total training time: 17.76 seconds.
# -- Epoch 958
# Norm: 28.63, NNZs: 5000, Bias: 0.798126, T: 58860478, Avg. loss: 0.187575
# Total training time: 17.78 seconds.
# -- Epoch 959
# Norm: 28.63, NNZs: 5000, Bias: 0.798269, T: 58921919, Avg. loss: 0.187573
# Total training time: 17.80 seconds.
# -- Epoch 960
# Norm: 28.63, NNZs: 5000, Bias: 0.798108, T: 58983360, Avg. loss: 0.187574
# Total training time: 17.82 seconds.
# -- Epoch 961
# Norm: 28.63, NNZs: 5000, Bias: 0.798269, T: 59044801, Avg. loss: 0.187573
# Total training time: 17.84 seconds.
# -- Epoch 962
# Norm: 28.63, NNZs: 5000, Bias: 0.798179, T: 59106242, Avg. loss: 0.187574
# Total training time: 17.85 seconds.
# -- Epoch 963
# Norm: 28.63, NNZs: 5000, Bias: 0.798211, T: 59167683, Avg. loss: 0.187574
# Total training time: 17.87 seconds.
# -- Epoch 964
# Norm: 28.63, NNZs: 5000, Bias: 0.798152, T: 59229124, Avg. loss: 0.187573
# Total training time: 17.90 seconds.
# -- Epoch 965
# Norm: 28.63, NNZs: 5000, Bias: 0.798132, T: 59290565, Avg. loss: 0.187574
# Total training time: 17.92 seconds.
# -- Epoch 966
# Norm: 28.63, NNZs: 5000, Bias: 0.798135, T: 59352006, Avg. loss: 0.187574
# Total training time: 17.93 seconds.
# -- Epoch 967
# Norm: 28.63, NNZs: 5000, Bias: 0.798203, T: 59413447, Avg. loss: 0.187574
# Total training time: 17.95 seconds.
# -- Epoch 968
# Norm: 28.63, NNZs: 5000, Bias: 0.798149, T: 59474888, Avg. loss: 0.187574
# Total training time: 17.97 seconds.
# -- Epoch 969
# Norm: 28.63, NNZs: 5000, Bias: 0.798156, T: 59536329, Avg. loss: 0.187574
# Total training time: 17.99 seconds.
# -- Epoch 970
# Norm: 28.63, NNZs: 5000, Bias: 0.798179, T: 59597770, Avg. loss: 0.187574
# Total training time: 18.00 seconds.
# -- Epoch 971
# Norm: 28.63, NNZs: 5000, Bias: 0.798144, T: 59659211, Avg. loss: 0.187574
# Total training time: 18.02 seconds.
# -- Epoch 972
# Norm: 28.63, NNZs: 5000, Bias: 0.798156, T: 59720652, Avg. loss: 0.187574
# Total training time: 18.04 seconds.
# -- Epoch 973
# Norm: 28.63, NNZs: 5000, Bias: 0.798196, T: 59782093, Avg. loss: 0.187574
# Total training time: 18.06 seconds.
# -- Epoch 974
# Norm: 28.63, NNZs: 5000, Bias: 0.798162, T: 59843534, Avg. loss: 0.187573
# Total training time: 18.08 seconds.
# -- Epoch 975
# Norm: 28.63, NNZs: 5000, Bias: 0.798162, T: 59904975, Avg. loss: 0.187574
# Total training time: 18.10 seconds.
# -- Epoch 976
# Norm: 28.63, NNZs: 5000, Bias: 0.798174, T: 59966416, Avg. loss: 0.187574
# Total training time: 18.12 seconds.
# -- Epoch 977
# Norm: 28.63, NNZs: 5000, Bias: 0.798124, T: 60027857, Avg. loss: 0.187573
# Total training time: 18.14 seconds.
# -- Epoch 978
# Norm: 28.63, NNZs: 5000, Bias: 0.798097, T: 60089298, Avg. loss: 0.187573
# Total training time: 18.16 seconds.
# -- Epoch 979
# Norm: 28.63, NNZs: 5000, Bias: 0.798192, T: 60150739, Avg. loss: 0.187574
# Total training time: 18.17 seconds.
# -- Epoch 980
# Norm: 28.63, NNZs: 5000, Bias: 0.798167, T: 60212180, Avg. loss: 0.187573
# Total training time: 18.19 seconds.
# -- Epoch 981
# Norm: 28.63, NNZs: 5000, Bias: 0.798201, T: 60273621, Avg. loss: 0.187573
# Total training time: 18.21 seconds.
# -- Epoch 982
# Norm: 28.63, NNZs: 5000, Bias: 0.798164, T: 60335062, Avg. loss: 0.187573
# Total training time: 18.23 seconds.
# -- Epoch 983
# Norm: 28.63, NNZs: 5000, Bias: 0.798232, T: 60396503, Avg. loss: 0.187574
# Total training time: 18.25 seconds.
# -- Epoch 984
# Norm: 28.63, NNZs: 5000, Bias: 0.798101, T: 60457944, Avg. loss: 0.187574
# Total training time: 18.26 seconds.
# -- Epoch 985
# Norm: 28.63, NNZs: 5000, Bias: 0.798126, T: 60519385, Avg. loss: 0.187574
# Total training time: 18.28 seconds.
# -- Epoch 986
# Norm: 28.63, NNZs: 5000, Bias: 0.798176, T: 60580826, Avg. loss: 0.187573
# Total training time: 18.30 seconds.
# -- Epoch 987
# Norm: 28.63, NNZs: 5000, Bias: 0.798136, T: 60642267, Avg. loss: 0.187573
# Total training time: 18.33 seconds.
# -- Epoch 988
# Norm: 28.63, NNZs: 5000, Bias: 0.798204, T: 60703708, Avg. loss: 0.187573
# Total training time: 18.34 seconds.
# -- Epoch 989
# Norm: 28.63, NNZs: 5000, Bias: 0.798143, T: 60765149, Avg. loss: 0.187572
# Total training time: 18.36 seconds.
# -- Epoch 990
# Norm: 28.63, NNZs: 5000, Bias: 0.798235, T: 60826590, Avg. loss: 0.187573
# Total training time: 18.38 seconds.
# -- Epoch 991
# Norm: 28.63, NNZs: 5000, Bias: 0.798184, T: 60888031, Avg. loss: 0.187573
# Total training time: 18.40 seconds.
# -- Epoch 992
# Norm: 28.63, NNZs: 5000, Bias: 0.798181, T: 60949472, Avg. loss: 0.187573
# Total training time: 18.41 seconds.
# -- Epoch 993
# Norm: 28.63, NNZs: 5000, Bias: 0.798161, T: 61010913, Avg. loss: 0.187573
# Total training time: 18.44 seconds.
# -- Epoch 994
# Norm: 28.63, NNZs: 5000, Bias: 0.798177, T: 61072354, Avg. loss: 0.187573
# Total training time: 18.45 seconds.
# -- Epoch 995
# Norm: 28.63, NNZs: 5000, Bias: 0.798213, T: 61133795, Avg. loss: 0.187572
# Total training time: 18.47 seconds.
# -- Epoch 996
# Norm: 28.63, NNZs: 5000, Bias: 0.798135, T: 61195236, Avg. loss: 0.187573
# Total training time: 18.49 seconds.
# -- Epoch 997
# Norm: 28.63, NNZs: 5000, Bias: 0.798228, T: 61256677, Avg. loss: 0.187573
# Total training time: 18.51 seconds.
# -- Epoch 998
# Norm: 28.63, NNZs: 5000, Bias: 0.798233, T: 61318118, Avg. loss: 0.187573
# Total training time: 18.53 seconds.
# -- Epoch 999
# Norm: 28.63, NNZs: 5000, Bias: 0.798270, T: 61379559, Avg. loss: 0.187573
# Total training time: 18.55 seconds.
# -- Epoch 1000
# Norm: 28.63, NNZs: 5000, Bias: 0.798205, T: 61441000, Avg. loss: 0.187573
# Total training time: 18.57 seconds.
# Saving Trained Model....
# Retraining Vectorizer with Dx_train
# Area Under the Curve for Train :  0.9661167505416866
# Area Under the Curve for Test :  0.9584876015436321

# %% [markdown]
# ### [5.1.3]  Applying Linear SVM on AVG W2V,<font color='red'> SET 3</font>

# %%
# Please write all the code with proper documentation

# %% [markdown]
# ### [5.1.4]  Applying Linear SVM on TFIDF W2V,<font color='red'> SET 4</font>

# %%
# Please write all the code with proper documentation

# %% [markdown]
# ## [5.2] RBF SVM

# %% [markdown]
# ### [5.2.1] Applying RBF SVM on BOW,<font color='red'> SET 1</font>

# %%
# Please write all the code with proper documentation

# %% [markdown]
# ### [5.2.2] Applying RBF SVM on TFIDF,<font color='red'> SET 2</font>

# %%
# Please write all the code with proper documentation

# %% [markdown]
# ### [5.2.3]  Applying RBF SVM on AVG W2V,<font color='red'> SET 3</font>

# %%
# Please write all the code with proper documentation

# %% [markdown]
# ### [5.2.4]  Applying RBF SVM on TFIDF W2V,<font color='red'> SET 4</font>

# %%
# Please write all the code with proper documentation

# %% [markdown]
# # [6] Conclusions

# %%
# Please compare all your models using Prettytable library
